# %%
import torch
from tqdm import tqdm
import os
import yaml
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from src.utils import (
    linearise_input, convert_to_features, form_stepwise_input, 
    simplify_feat_names,
    label_qs,
    simplify_narr_question
)

# %%
config_type = 'essel_test'
model_base = '../models/bart-base/pretty-night-126/checkpoint-517'
output_dir = '../models/bart-base/pretty-night-126/'

# import yaml file
with open('../configs/train_default.yaml') as f:
    args = yaml.safe_load(f)

# Update default args with chosen config
if config_type != 'default':
    with open('../configs/train_configs.yaml') as f:
        yaml_configs = yaml.safe_load_all(f)
        yaml_args = next(
            conf for conf in yaml_configs if conf['config'] == config_type)
    args.update(yaml_args)
    print(f'Updating with:\n{yaml_args}\n')
print(f'\n{args}\n')

# Load model, tokenizer and dataset
model = AutoModelForSeq2SeqLM.from_pretrained(model_base, return_dict=True).to('cuda')
tokenizer = AutoTokenizer.from_pretrained(model_base)
dataset = load_dataset("james-burton/textual-explanations") if not args['augmented_ds'] else \
    load_dataset("james-burton/aug-text-exps")

if args['simplify_narr_qs']:
    dataset = dataset.map(lambda x: simplify_narr_question(label_qs(x)),
                            load_from_cache_file=False)

# Form the linearised or stepwise (and linearised) input
dataset = dataset.map(
    lambda x: linearise_input(x, args['linearisation'], args['max_features']),
    load_from_cache_file=False
    ) 

# Convert to tokens
dataset = dataset.map(
    lambda x: convert_to_features(x, tokenizer, args['max_input_len']), 
    batched=True, load_from_cache_file=False
    )
# Out:
# Updating with:
# {'config': 'essel_test', 'fast_dev_run': True, 'do_train': True, 'linearisation': 'text', 'max_features': 15, 'tags': ['t5-base'], 'batch_size': 4, 'simplify_narr_qs': True}
#
#
# {'config': 'essel_test', 'fast_dev_run': True, 'do_train': True, 'do_predict': True, 'tags': ['t5-base'], 'batch_size': 4, 'linearisation': 'text', 'max_features': 15, 'model_base': 't5-base', 'output_root': 'models/t5-base/', 'max_input_len': 400, 'lr': 5e-05, 'weight_decay': 0.3, 'num_epochs': 50, 'early_stopping_patience': 3, 'grad_accumulation_steps': 1, 'seed': 43, 'logging_steps': 10, 'lr_scheduler': 'linear', 'warmup_ratio': 0.1, 'device': 'cuda', 'num_workers': 1, 'resume_from_checkpoint': False, 'eval_accumulation_steps': None, 'num_beams': 4, 'repetition_penalty': 3.5, 'length_penalty': 1.5, 'max_output_len': 250, 'predict_batch_size': 4, 'save_total_limit': 1, 'augmented_ds': False, 'simplify_narr_qs': True}
# Using custom data configuration james-burton--textual-explanations-65605998b9ae8604
# Found cached dataset parquet (/home/james/.cache/huggingface/datasets/james-burton___parquet/james-burton--textual-explanations-65605998b9ae8604/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|██████████| 3/3 [00:00<00:00, 898.91it/s]
# 100%|██████████| 375/375 [00:00<00:00, 7529.20ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 6878.31ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 6872.55ex/s]
# 100%|██████████| 375/375 [00:00<00:00, 2703.64ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2811.24ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2691.81ex/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.58ba/s]
# 100%|██████████| 1/1 [00:00<00:00, 63.95ba/s]
# 100%|██████████| 1/1 [00:00<00:00, 60.31ba/s]

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=args['num_beams'],
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"]*4,
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=False)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_len-penx4.txt'), 'w') as f:
    for input, pred in zip(dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
#   8%|▊         | 1/12 [00:12<02:16, 12.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 all_preds = []
#       5 for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
# ----> 6     sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
#       7                                             attention_mask=attention_mask[i:i+args['predict_batch_size']],
#       8                                             num_beams=args['num_beams'],
#       9                                             repetition_penalty=args["repetition_penalty"],
#      10                                             length_penalty=args["length_penalty"]*4,
#      11                                             max_length=args['max_output_len'],
#      12                                             no_repeat_ngram_size=2,
#      13                                             num_return_sequences=1,
#      14                                             do_sample=True,
#      15                                             early_stopping=True,
#      16                                             use_cache=False)
#      17     preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
#      18     all_preds.extend(preds)
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/utils.py:1652, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, penalty_alpha, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, suppress_tokens, begin_suppress_tokens, forced_decoder_ids, **model_kwargs)
#    1644     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1645         input_ids=input_ids,
#    1646         expand_size=num_beams * num_return_sequences,
#    1647         is_encoder_decoder=self.config.is_encoder_decoder,
#    1648         **model_kwargs,
#    1649     )
#    1651     # 13. run beam sample
# -> 1652     return self.beam_sample(
#    1653         input_ids,
#    1654         beam_scorer,
#    1655         logits_processor=logits_processor,
#    1656         logits_warper=logits_warper,
#    1657         stopping_criteria=stopping_criteria,
#    1658         pad_token_id=pad_token_id,
#    1659         eos_token_id=eos_token_id,
#    1660         output_scores=output_scores,
#    1661         return_dict_in_generate=return_dict_in_generate,
#    1662         synced_gpus=synced_gpus,
#    1663         **model_kwargs,
#    1664     )
#    1666 elif is_group_beam_gen_mode:
#    1667     if num_return_sequences > num_beams:
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/utils.py:3131, in GenerationMixin.beam_sample(self, input_ids, beam_scorer, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3126 next_token_logits = self.adjust_logits_during_generation(next_token_logits, cur_len=cur_len)
#    3127 next_token_scores = nn.functional.log_softmax(
#    3128     next_token_logits, dim=-1
#    3129 )  # (batch_size * num_beams, vocab_size)
# -> 3131 next_token_scores_processed = logits_processor(input_ids, next_token_scores)
#    3132 next_token_scores = next_token_scores_processed + beam_scores[:, None].expand_as(next_token_scores)
#    3133 next_token_scores = logits_warper(input_ids, next_token_scores)
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/logits_process.py:92, in LogitsProcessorList.__call__(self, input_ids, scores, **kwargs)
#      90         scores = processor(input_ids, scores, **kwargs)
#      91     else:
# ---> 92         scores = processor(input_ids, scores)
#      93 return scores
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/logits_process.py:340, in NoRepeatNGramLogitsProcessor.__call__(self, input_ids, scores)
#     338 num_batch_hypotheses = scores.shape[0]
#     339 cur_len = input_ids.shape[-1]
# --> 340 banned_batch_tokens = _calc_banned_ngram_tokens(self.ngram_size, input_ids, num_batch_hypotheses, cur_len)
#     342 for i, banned_tokens in enumerate(banned_batch_tokens):
#     343     scores[i, banned_tokens] = -float("inf")
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/logits_process.py:313, in _calc_banned_ngram_tokens(ngram_size, prev_input_ids, num_hypos, cur_len)
#     309 if cur_len + 1 < ngram_size:
#     310     # return no banned tokens if we haven't generated no_repeat_ngram_size tokens yet
#     311     return [[] for _ in range(num_hypos)]
# --> 313 generated_ngrams = _get_ngrams(ngram_size, prev_input_ids, num_hypos)
#     315 banned_tokens = [
#     316     _get_generated_ngrams(generated_ngrams[hypo_idx], prev_input_ids[hypo_idx], ngram_size, cur_len)
#     317     for hypo_idx in range(num_hypos)
#     318 ]
#     319 return banned_tokens
#
# File ~/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/logits_process.py:290, in _get_ngrams(ngram_size, prev_input_ids, num_hypos)
#     288 generated_ngrams = [{} for _ in range(num_hypos)]
#     289 for idx in range(num_hypos):
# --> 290     gen_tokens = prev_input_ids[idx].tolist()
#     291     generated_ngram = generated_ngrams[idx]
#     292     for ngram in zip(*[gen_tokens[i:] for i in range(ngram_size)]):
#
# KeyboardInterrupt:

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=10,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=False)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams10.txt'), 'w') as f:
    for input, pred in zip(dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
# 100%|██████████| 12/12 [06:13<00:00, 31.13s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=10,
                                            num_beam_groups=5,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            early_stopping=True,
                                            use_cache=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams10v2.txt'), 'w') as f:
    for input, pred in zip(dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
#   0%|          | 0/12 [00:00<?, ?it/s]/home/james/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 100%|██████████| 12/12 [00:40<00:00,  3.39s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=10,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams10v3.txt'), 'w') as f:
    for input, pred in zip(dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
# 100%|██████████| 12/12 [00:40<00:00,  3.34s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=10,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"]*3,
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams10v4.txt'), 'w') as f:
    for input, pred in zip(dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
# 100%|██████████| 12/12 [00:48<00:00,  4.08s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=20,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams20.txt'), 'w') as f:
    for ans, input, pred in zip(dataset['test']['narration'], dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'GOLD: {ans} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
# 100%|██████████| 12/12 [01:08<00:00,  5.74s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=20,
                                            num_beam_groups=5,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            early_stopping=True,
                                            use_cache=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams20v2.txt'), 'w') as f:
    for ans, input, pred in zip(dataset['test']['narration'], dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'GOLD: {ans} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
#   0%|          | 0/12 [00:00<?, ?it/s]/home/james/CodingProjects/Local_level_model_explanations/env/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(
# 100%|██████████| 12/12 [01:06<00:00,  5.56s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %% [markdown]
# # Substituing feature names

# %%
print("***** Running Prediction *****")
input_ids = torch.tensor(dataset['test']['input_ids']).to(model.device)
attention_mask = torch.tensor(dataset['test']['attention_mask']).to(model.device)
all_preds = []
for i in tqdm(range(0,input_ids.shape[0],args['predict_batch_size'])):
    sample_outputs = model.generate(input_ids=input_ids[i:i+args['predict_batch_size']],
                                            attention_mask=attention_mask[i:i+args['predict_batch_size']],
                                            num_beams=20,
                                            repetition_penalty=args["repetition_penalty"],
                                            length_penalty=args["length_penalty"],
                                            max_length=args['max_output_len'],
                                            no_repeat_ngram_size=2,
                                            num_return_sequences=1,
                                            do_sample=True,
                                            early_stopping=True,
                                            use_cache=True,
                                            renormalize_logits=True)
    preds = tokenizer.batch_decode(sample_outputs, skip_special_tokens=True)
    all_preds.extend(preds)
# Save the predictions
readable_predictions = ['.\n'.join(pred.split('. ')) for pred in all_preds]
print(f'Saving predictions to {output_dir}')
with open(os.path.join(output_dir, 'test_predictions_readable_beams20v3.txt'), 'w') as f:
    for ans, input, pred in zip(dataset['test']['narration'], dataset['test']['input'], readable_predictions):
        f.write(f'INPUT: {input} \n\n')
        f.write(f'GOLD: {ans} \n\n')
        f.write(f'OUTPUT: {pred} \n\n')
    f.write('\n\n'.join(readable_predictions))
# Out:
# ***** Running Prediction *****
# 100%|██████████| 12/12 [00:55<00:00,  4.64s/it]
# Saving predictions to ../models/bart-base/pretty-night-126/

# %%
def new2old(row):
    row['new2old_classes'] = {v: k for k, v in eval(row['old2new_classes']).items() if k != None}
    return row

dataset = dataset.map(new2old)
# Out:
# 100%|██████████| 375/375 [00:00<00:00, 2250.05ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2346.48ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2401.07ex/s]

# %%
dataset['train']['new2old_classes']
# Out:
# ["{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C4': 'C1', 'C1': 'C2', 'C3': 'C3', 'C2': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C4': 'C3', 'C3': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3', 'C4': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C4': 'C2', 'C2': 'C3', 'C1': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C4': 'C3', 'C3': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C2', 'C2': 'C1'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C3': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C2', 'C2': 'C1'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3', 'C4': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C4': 'C2', 'C2': 'C3', 'C1': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C4': 'C2', 'C2': 'C3', 'C3': 'C4'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3', 'C4': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C4', 'C4': 'C2', 'C1': 'C3', 'C3': 'C1'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C3': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3'}",
#  "{'C1': 'C1', 'C4': 'C2', 'C2': 'C3', 'C3': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C4': 'C1', 'C3': 'C2', 'C1': 'C3', 'C2': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2', 'C4': 'C3', 'C3': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C4': 'C3', 'C2': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C3': 'C2', 'C1': 'C3', 'C4': 'C4'}",
#  "{'C1': 'C1', 'C3': 'C2', 'C4': 'C3', 'C2': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C4': 'C2', 'C2': 'C3', 'C3': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C4': 'C1', 'C1': 'C2', 'C2': 'C3', 'C3': 'C4'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3', 'C4': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C3': 'C1', 'C1': 'C2', 'C2': 'C3', 'C4': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2', 'C3': 'C3'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C1': 'C1', 'C2': 'C2'}",
#  "{'C2': 'C2', 'C1': 'C1'}",
#  "{'C3': 'C1', 'C2': 'C2', 'C1': 'C3', 'C4': 'C4'}",
#  "{'C2': 'C1', 'C1': 'C2'}",
#  "{'C2': 'C1', 'C1': 'C2'}"]

# %%
import json

# %%
all_train = json.load(open('../data/raw/all_train.json',encoding='utf-8'))
test = json.load(open('../data/raw/test_set_new.json',encoding='utf-8'))
all = all_train + test
no_task = [x for x in all if x.get('task_name', None) == None]
all = [x for x in all if x.get('task_name', None) != None]

sign_dict = {'red': 'negative', 'green': 'positive', 'yellow': 'negligible'}

# %%
tasknames = set([(a['task_name'], a['predicted_class'], a['predicted_class_label']) for a in all])
task2name_dict = {f'{t}_{c}': name for (t, c, name) in tasknames}
task2name_dict.update({'Air Quality Prediction_C4': 'Other',
                       'Cab Surge Pricing System_C1': 'Low',
                       'Cab Surge Pricing System_C2': 'Medium',
                       'Cab Surge Pricing System_C3': 'High',
                       'Car Acceptability Valuation_C3': 'Other A',
                       'Car Acceptability Valuation_C4': 'Other B',
                       'Concrete Strength Classification_C3': 'Other',
                       'Customer Churn Modelling_C3': 'Other',
                       'Flight Price-Range Classification_C4': 'Special',
                       'Food Ordering Customer Churn Prediction_C3': 'Accept',
                       'German Credit Evaluation_C3': 'Other',
                       'Mobile Price-Range Classification_C3': 'r3',
                       'Suspicious Bidding Identification_C2': 'Suspicious',
                       'Used Cars Price-Range Prediction_C3': 'Medium',
                       'Wine Quality Prediction_C1': 'low_quality',
                       })

# %%
tasknames
# Out:
# {('Advertisement Prediction', 'C1', 'Skip'),
#  ('Advertisement Prediction', 'C2', 'Watch'),
#  ('Air Quality Prediction', 'C1', 'Preparing meals'),
#  ('Air Quality Prediction', 'C2', 'Presence of smoke'),
#  ('Air Quality Prediction', 'C3', 'Cleaning'),
#  ('Airline Passenger Satisfaction', 'C1', 'neutral or dissatisfied'),
#  ('Airline Passenger Satisfaction', 'C2', 'Acceptable'),
#  ('Airline Passenger Satisfaction', 'C2', 'satisfied'),
#  ('Annual Income Earnings', 'C1', 'Under 50K'),
#  ('Annual Income Earnings', 'C2', 'Above 50K'),
#  ('Australian Credit Approval', 'C1', 'Class 1'),
#  ('Australian Credit Approval', 'C2', 'Class 2'),
#  ('Basketball Players Career Length Prediction', 'C1', 'More than 5'),
#  ('Basketball Players Career Length Prediction', 'C2', 'Less than 5'),
#  ('Bike Sharing Demand', 'C1', 'Less than 500'),
#  ('Bike Sharing Demand', 'C2', 'More than 500'),
#  ('Broadband Sevice Signup', 'C1', 'No'),
#  ('Broadband Sevice Signup', 'C2', 'Yes'),
#  ('Cab Surge Pricing System', 'C1', 'C1'),
#  ('Cab Surge Pricing System', 'C2', 'C2'),
#  ('Cab Surge Pricing System', 'C3', 'C3'),
#  ('Car Acceptability Valuation', 'C1', 'Unacceptable'),
#  ('Car Acceptability Valuation', 'C2', 'Acceptable'),
#  ('Company Bankruptcy Prediction', 'C1', 'No'),
#  ('Company Bankruptcy Prediction', 'C2', 'Yes'),
#  ('Concrete Strength Classification', 'C1', 'Weak'),
#  ('Concrete Strength Classification', 'C2', 'Strong'),
#  ('Credit Card Fraud Classification', 'C1', 'Not Fraud'),
#  ('Credit Card Fraud Classification', 'C2', 'Fraud'),
#  ('Credit Risk Classification', 'C1', 'Low'),
#  ('Credit Risk Classification', 'C2', 'High'),
#  ('Customer Churn Modelling', 'C1', 'Stay'),
#  ('Customer Churn Modelling', 'C2', 'Leave'),
#  ('E-Commerce Shipping', 'C1', 'On-time'),
#  ('E-Commerce Shipping', 'C2', 'Late'),
#  ('Employee Attrition', 'C1', 'Leave'),
#  ('Employee Attrition', 'C1', 'Stay'),
#  ('Employee Attrition', 'C2', 'Leave'),
#  ('Employee Promotion Prediction', 'C1', 'Ignore'),
#  ('Employee Promotion Prediction', 'C2', 'Promote'),
#  ('Ethereum Fraud Detection', 'C1', 'Not Fraud'),
#  ('Ethereum Fraud Detection', 'C2', 'Fraud'),
#  ('Flight Price-Range Classification', 'C1', 'Low'),
#  ('Flight Price-Range Classification', 'C2', 'Moderate'),
#  ('Flight Price-Range Classification', 'C3', 'High'),
#  ('Food Ordering Customer Churn Prediction', 'C1', 'Return'),
#  ('Food Ordering Customer Churn Prediction', 'C2', 'Go Away'),
#  ('German Credit Evaluation', 'C1', 'Good Credit'),
#  ('German Credit Evaluation', 'C2', 'Bad Credit'),
#  ('Health Care Services Satisfaction Prediction', 'C1', 'Dissatisfied'),
#  ('Health Care Services Satisfaction Prediction', 'C2', 'Satisfied'),
#  ('Hotel Satisfaction', 'C1', 'dissatisfied'),
#  ('Hotel Satisfaction', 'C2', 'satisfied'),
#  ('House Price Classification', 'C1', 'Low'),
#  ('House Price Classification', 'C2', 'High'),
#  ('Insurance Churn', 'C1', 'Stay'),
#  ('Insurance Churn', 'C2', 'Leave'),
#  ('Job Change of Data Scientists', 'C1', 'Stay'),
#  ('Job Change of Data Scientists', 'C2', 'Leave'),
#  ('Mobile Price-Range Classification', 'C1', 'r1'),
#  ('Mobile Price-Range Classification', 'C2', 'r2'),
#  ('Mobile Price-Range Classification', 'C4', 'r4'),
#  ('Music Concert Attendance', 'C1', '< 10k'),
#  ('Music Concert Attendance', 'C2', '> 10k'),
#  ('Paris House Classification', 'C1', 'Basic'),
#  ('Paris House Classification', 'C2', 'Luxury'),
#  ('Personal Loan Modelling', 'C1', 'Reject'),
#  ('Personal Loan Modelling', 'C2', 'Accept'),
#  ('Printer Sales', 'C1', 'Less'),
#  ('Printer Sales', 'C2', 'More'),
#  ('Real Estate Investment', 'C1', 'Ignore'),
#  ('Real Estate Investment', 'C2', 'Invest'),
#  ('Student Job Placement', 'C1', 'Not Placed'),
#  ('Student Job Placement', 'C2', 'Placed'),
#  ('Suspicious Bidding Identification', 'C1', 'Normal'),
#  ('Tic-Tac-Toe Strategy', 'C1', 'player B lose'),
#  ('Tic-Tac-Toe Strategy', 'C2', 'player B win'),
#  ('Used Cars Price-Range Prediction', 'C1', 'Low'),
#  ('Used Cars Price-Range Prediction', 'C2', 'High'),
#  ('Vehicle Insurance Claims', 'C1', 'Fraud'),
#  ('Vehicle Insurance Claims', 'C1', 'Not Fraud'),
#  ('Vehicle Insurance Claims', 'C2', 'Fraud'),
#  ('Water Quality Classification', 'C1', 'Not Portable'),
#  ('Water Quality Classification', 'C2', 'Portable'),
#  ('Wine Quality Prediction', 'C2', 'high quality')}

# %%
tasknames = set([(a['task_name'], a['new2old_classes'][a['predicted_class']], a['predicted_class_label']) for a in dataset['train']])
tasknames.update(set([(a['task_name'], a['new2old_classes'][a['predicted_class']], a['predicted_class_label']) for a in dataset['validation']]))
tasknames.update(set([(a['task_name'], a['new2old_classes'][a['predicted_class']], a['predicted_class_label']) for a in dataset['test']]))
initial_taskname_dict = {f'{t}_{c}': name for (t, c, name) in tasknames}

task_class2name_dict = {}
for row in dataset['train']:
    new_keys = list(eval(row['classes_dict']).keys())
    old_keys = [row['new2old_classes'][str(k)] for k in new_keys]
    for key in old_keys:
        task_class2name_dict[f"{row['task_name']}_{key}"] = initial_taskname_dict.get(f"{row['task_name']}_{key}", 0)

for row in dataset['validation']:
    new_keys = list(eval(row['classes_dict']).keys())
    old_keys = [row['new2old_classes'][str(k)] for k in new_keys]
    for key in old_keys:
        task_class2name_dict[f"{row['task_name']}_{key}"] = initial_taskname_dict.get(f"{row['task_name']}_{key}", 0)
        
for row in dataset['test']:
    new_keys = list(eval(row['classes_dict']).keys())
    old_keys = [row['new2old_classes'][str(k)] for k in new_keys]
    for key in old_keys:
        task_class2name_dict[f"{row['task_name']}_{key}"] = initial_taskname_dict.get(f"{row['task_name']}_{key}", 0)

task_class2name_dict.update({'Air Quality Prediction_C4': 'Other',
                'Cab Surge Pricing System_C1': 'Low',
                'Cab Surge Pricing System_C2': 'Medium',
                'Cab Surge Pricing System_C3': 'High',
                'Car Acceptability Valuation_C3': 'Other A',
                'Car Acceptability Valuation_C4': 'Other B',
                'Concrete Strength Classification_C3': 'Other',
                'Customer Churn Modelling_C3': 'Other',
                'Flight Price-Range Classification_C4': 'Special',
                'Food Ordering Customer Churn Prediction_C3': 'Accept',
                'German Credit Evaluation_C3': 'Other',
                'Mobile Price-Range Classification_C3' :'r3', 
                'Suspicious Bidding Identification_C2': 'Suspicious',
                'Used Cars Price-Range Prediction_C3': 'Medium',
                'Wine Quality Prediction_C1': 'low_quality',
                })
task_class2name_dict = dict(sorted(task_class2name_dict.items()))

def class2name(row):
    classes_dict = eval(row['classes_dict'])
    task_classes = [f"{row['task_name']}_{row['new2old_classes'][c]}" for c in classes_dict.keys()]
    row['class2name'] = {c: task_class2name_dict[t_c] for c, t_c in zip(classes_dict.keys(), task_classes)}
    return row

dataset = dataset.map(class2name)
# Out:
# 100%|██████████| 375/375 [00:00<00:00, 2101.04ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2097.69ex/s]
# 100%|██████████| 47/47 [00:00<00:00, 2087.56ex/s]

# %%
import re

# %%
row = dataset['test'][0]
cls_ptn = re.compile("|".join([f'{k}\\b' for k in row['class2name'].keys() if k != None]))
narr = cls_ptn.sub(lambda x: f'\"{row["class2name"][x.group()]}\"', row['narration'])
ft_ptn = re.compile("|".join([f'{k}\\b' for k in eval(row['ft_num2name']).keys()]))
narr = ft_ptn.sub(lambda x: eval(row["ft_num2name"])[x.group()], narr)

# %%
narr
# Out:
# 'The classification decision of the classifier is: the case is likely to be "Invest" with approximately 99.28% certainty. This is because the classifier indicates that there is only a 0.72% chance that "Ignore" is the correct label. The variables that have the greatest impact on this judgement or classification decision are Feature2, Feature4, Feature14, and Feature7. From the analysis performed, the less important or less relevant variables are Feature19, Feature9, and Feature11. Regarding the direction of influence of the features, the values Feature7, Feature4, and Feature14 produce positive impacts, shifting the output decision in favour of "Invest" and together with other positives, Feature1, Feature17, and Feature12, increase the odds that "Invest" is the correct label. On the other hand, features such as Feature2, Feature8, Feature15, Feature13, and Feature20 have negative contributions, prompting the classifier to assign "Ignore" in this case, hence the assigned likelihood of 0.72%.'

# %%
{c: task_class2name_dict[t_c] for c, t_c in zip(classes_dict.keys(), task_classes)}
# Out:
# {'C2': 'Ignore', 'C1': 'Invest'}

# %%
dataset['train']['class2name']
# Out:
# [{'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Invest', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'Unacceptable', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Moderate', 'C3': 'Low', 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'Less', 'C2': 'More', 'C3': None, 'C4': None},
#  {'C1': '< 10k', 'C2': '> 10k', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'neutral or dissatisfied', 'C2': 'Acceptable', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Moderate', 'C3': 'Low', 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': 'Medium', 'C4': None},
#  {'C1': 'low_quality', 'C2': 'high quality', 'C3': None, 'C4': None},
#  {'C1': 'On-time', 'C2': 'Late', 'C3': None, 'C4': None},
#  {'C1': 'Skip', 'C2': 'Watch', 'C3': None, 'C4': None},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'r2', 'C2': 'r4', 'C3': 'r3', 'C4': 'r1'},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'player B lose', 'C2': 'player B win', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'r1', 'C2': 'r2', 'C3': 'r4', 'C4': 'r3'},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'Accept', 'C2': 'Reject', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Less', 'C2': 'More', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'r1', 'C2': 'r3', 'C3': 'r2', 'C4': 'r4'},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Moderate', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Portable', 'C2': 'Not Portable', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Bad Credit', 'C2': 'Good Credit', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Bad Credit', 'C2': 'Other', 'C3': 'Good Credit', 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Basic', 'C2': 'Luxury', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'Basic', 'C2': 'Luxury', 'C3': None, 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'r4', 'C2': 'r3', 'C3': 'r1', 'C4': 'r2'},
#  {'C1': 'Portable', 'C2': 'Not Portable', 'C3': None, 'C4': None},
#  {'C1': 'r2', 'C2': 'r1', 'C3': 'r4', 'C4': 'r3'},
#  {'C1': 'Reject', 'C2': 'Accept', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Not Portable', 'C2': 'Portable', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Under 50K', 'C2': 'Above 50K', 'C3': None, 'C4': None},
#  {'C1': 'Unacceptable', 'C2': 'Acceptable', 'C3': None, 'C4': None},
#  {'C1': 'Invest', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'Above 50K', 'C2': 'Under 50K', 'C3': None, 'C4': None},
#  {'C1': 'low_quality', 'C2': 'high quality', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Less', 'C2': 'More', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': 'Other', 'C4': None},
#  {'C1': 'More than 5', 'C2': 'Less than 5', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Accept', 'C2': 'Reject', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'high quality', 'C2': 'low_quality', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'Moderate', 'C3': 'High', 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'Moderate', 'C3': 'High', 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'neutral or dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Reject', 'C2': 'Accept', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Not Fraud', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Strong', 'C2': 'Other', 'C3': 'Weak', 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Under 50K', 'C2': 'Above 50K', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Not Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Basic', 'C2': 'Luxury', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'Portable', 'C2': 'Not Portable', 'C3': None, 'C4': None},
#  {'C1': 'Less', 'C2': 'More', 'C3': None, 'C4': None},
#  {'C1': 'Under 50K', 'C2': 'Above 50K', 'C3': None, 'C4': None},
#  {'C1': 'Late', 'C2': 'On-time', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'Not Placed', 'C2': 'Placed', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Moderate', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'Class 2', 'C2': 'Class 1', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Accept', 'C2': 'Reject', 'C3': None, 'C4': None},
#  {'C1': 'Less than 500', 'C2': 'More than 500', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'neutral or dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Moderate', 'C3': 'Low', 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'On-time', 'C2': 'Late', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'Ignore', 'C2': 'Promote', 'C3': None, 'C4': None},
#  {'C1': 'Suspicious', 'C2': 'Normal', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'Skip', 'C2': 'Watch', 'C3': None, 'C4': None},
#  {'C1': 'Not Portable', 'C2': 'Portable', 'C3': None, 'C4': None},
#  {'C1': 'Not Placed', 'C2': 'Placed', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'More than 500', 'C2': 'Less than 500', 'C3': None, 'C4': None},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'Bad Credit', 'C2': 'Good Credit', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Under 50K', 'C2': 'Above 50K', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Class 2', 'C2': 'Class 1', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'Suspicious', 'C2': 'Normal', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'Invest', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Less', 'C2': 'More', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Strong', 'C2': 'Weak', 'C3': None, 'C4': None},
#  {'C1': 'Suspicious', 'C2': 'Normal', 'C3': None, 'C4': None},
#  {'C1': 'Dissatisfied', 'C2': 'Satisfied', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': 'Moderate', 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'Strong', 'C2': 'Weak', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'Late', 'C2': 'On-time', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'dissatisfied', 'C2': 'satisfied', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'More than 500', 'C2': 'Less than 500', 'C3': None, 'C4': None},
#  {'C1': 'Skip', 'C2': 'Watch', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Cleaning',
#   'C2': 'Presence of smoke',
#   'C3': 'Preparing meals',
#   'C4': 'Other'},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Moderate', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'Above 50K', 'C2': 'Under 50K', 'C3': None, 'C4': None},
#  {'C1': 'r4', 'C2': 'r3', 'C3': 'r1', 'C4': 'r2'},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'high quality', 'C2': 'low_quality', 'C3': None, 'C4': None},
#  {'C1': 'Class 1', 'C2': 'Class 2', 'C3': None, 'C4': None},
#  {'C1': 'On-time', 'C2': 'Late', 'C3': None, 'C4': None},
#  {'C1': 'low_quality', 'C2': 'high quality', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': 'Medium', 'C4': None},
#  {'C1': 'Reject', 'C2': 'Accept', 'C3': None, 'C4': None},
#  {'C1': 'dissatisfied', 'C2': 'satisfied', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'r1', 'C2': 'r3', 'C3': 'r4', 'C4': 'r2'},
#  {'C1': 'r3', 'C2': 'r1', 'C3': 'r2', 'C4': 'r4'},
#  {'C1': 'Basic', 'C2': 'Luxury', 'C3': None, 'C4': None},
#  {'C1': 'Less than 5', 'C2': 'More than 5', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': 'Medium', 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'Moderate', 'C3': 'High', 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'More than 5', 'C2': 'Less than 5', 'C3': None, 'C4': None},
#  {'C1': 'Reject', 'C2': 'Accept', 'C3': None, 'C4': None},
#  {'C1': 'Ignore', 'C2': 'Invest', 'C3': None, 'C4': None},
#  {'C1': 'player B lose', 'C2': 'player B win', 'C3': None, 'C4': None},
#  {'C1': 'dissatisfied', 'C2': 'satisfied', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Strong', 'C2': 'Weak', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Not Placed', 'C2': 'Placed', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'Reject', 'C2': 'Accept', 'C3': None, 'C4': None},
#  {'C1': 'Other A', 'C2': 'Other B', 'C3': 'Unacceptable', 'C4': 'Acceptable'},
#  {'C1': 'Bad Credit', 'C2': 'Good Credit', 'C3': None, 'C4': None},
#  {'C1': 'player B lose', 'C2': 'player B win', 'C3': None, 'C4': None},
#  {'C1': 'Not Portable', 'C2': 'Portable', 'C3': None, 'C4': None},
#  {'C1': 'Class 1', 'C2': 'Class 2', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Not Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Not Placed', 'C2': 'Placed', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'high quality', 'C2': 'low_quality', 'C3': None, 'C4': None},
#  {'C1': '> 10k', 'C2': '< 10k', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Strong', 'C2': 'Weak', 'C3': None, 'C4': None},
#  {'C1': 'On-time', 'C2': 'Late', 'C3': None, 'C4': None},
#  {'C1': 'neutral or dissatisfied', 'C2': 'Acceptable', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Ignore', 'C2': 'Invest', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'Invest', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'Medium', 'C3': 'High', 'C4': None},
#  {'C1': '> 10k', 'C2': '< 10k', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Promote', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Ignore', 'C2': 'Promote', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Late', 'C2': 'On-time', 'C3': None, 'C4': None},
#  {'C1': 'On-time', 'C2': 'Late', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'low_quality', 'C2': 'high quality', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'More than 5', 'C2': 'Less than 5', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'Moderate', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'No', 'C2': 'Yes', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'neutral or dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'Dissatisfied', 'C2': 'Satisfied', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': 'Medium', 'C4': None},
#  {'C1': 'r1', 'C2': 'r3', 'C3': 'r4', 'C4': 'r2'},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Above 50K', 'C2': 'Under 50K', 'C3': None, 'C4': None},
#  {'C1': 'player B win', 'C2': 'player B lose', 'C3': None, 'C4': None},
#  {'C1': 'r3', 'C2': 'r4', 'C3': 'r2', 'C4': 'r1'},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'player B lose', 'C2': 'player B win', 'C3': None, 'C4': None},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': '< 10k', 'C2': '> 10k', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Good Credit', 'C2': 'Bad Credit', 'C3': None, 'C4': None},
#  {'C1': 'satisfied', 'C2': 'dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Unacceptable', 'C2': 'Acceptable', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'Moderate', 'C3': 'Special', 'C4': 'High'},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'Presence of smoke',
#   'C2': 'Other',
#   'C3': 'Preparing meals',
#   'C4': 'Cleaning'},
#  {'C1': 'Bad Credit', 'C2': 'Good Credit', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Suspicious', 'C2': 'Normal', 'C3': None, 'C4': None},
#  {'C1': 'Above 50K', 'C2': 'Under 50K', 'C3': None, 'C4': None},
#  {'C1': 'Class 1', 'C2': 'Class 2', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'Portable', 'C2': 'Not Portable', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'Cleaning',
#   'C2': 'Preparing meals',
#   'C3': 'Presence of smoke',
#   'C4': 'Other'},
#  {'C1': 'r1', 'C2': 'r4', 'C3': 'r2', 'C4': 'r3'},
#  {'C1': 'Class 2', 'C2': 'Class 1', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Preparing meals',
#   'C2': 'Cleaning',
#   'C3': 'Other',
#   'C4': 'Presence of smoke'},
#  {'C1': 'Fraud', 'C2': 'Not Fraud', 'C3': None, 'C4': None},
#  {'C1': 'r2', 'C2': 'r3', 'C3': 'r4', 'C4': 'r1'},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'More', 'C2': 'Less', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'Late', 'C2': 'On-time', 'C3': None, 'C4': None},
#  {'C1': 'Presence of smoke',
#   'C2': 'Preparing meals',
#   'C3': 'Cleaning',
#   'C4': 'Other'},
#  {'C1': 'Above 50K', 'C2': 'Under 50K', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'Medium', 'C2': 'High', 'C3': 'Low', 'C4': None},
#  {'C1': 'Moderate', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'high quality', 'C2': 'low_quality', 'C3': None, 'C4': None},
#  {'C1': 'Not Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'r2', 'C2': 'r3', 'C3': 'r1', 'C4': 'r4'},
#  {'C1': 'Go Away', 'C2': 'Return', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Medium', 'C3': 'Low', 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Moderate', 'C2': 'Low', 'C3': 'High', 'C4': None},
#  {'C1': 'low_quality', 'C2': 'high quality', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Satisfied', 'C2': 'Dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'Weak', 'C2': 'Strong', 'C3': None, 'C4': None},
#  {'C1': 'More than 5', 'C2': 'Less than 5', 'C3': None, 'C4': None},
#  {'C1': 'Luxury', 'C2': 'Basic', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Low', 'C2': 'High', 'C3': None, 'C4': None},
#  {'C1': 'Yes', 'C2': 'No', 'C3': None, 'C4': None},
#  {'C1': 'Suspicious', 'C2': 'Normal', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Leave', 'C2': 'Stay', 'C3': None, 'C4': None},
#  {'C1': 'Invest', 'C2': 'Ignore', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Bad Credit', 'C2': 'Good Credit', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Placed', 'C2': 'Not Placed', 'C3': None, 'C4': None},
#  {'C1': 'Watch', 'C2': 'Skip', 'C3': None, 'C4': None},
#  {'C1': 'Class 2', 'C2': 'Class 1', 'C3': None, 'C4': None},
#  {'C1': 'Return', 'C2': 'Go Away', 'C3': None, 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'neutral or dissatisfied', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'High', 'C2': 'Low', 'C3': None, 'C4': None},
#  {'C1': 'Accept', 'C2': 'Reject', 'C3': None, 'C4': None},
#  {'C1': 'Stay', 'C2': 'Leave', 'C3': None, 'C4': None},
#  {'C1': 'Fraud', 'C2': 'Fraud', 'C3': None, 'C4': None},
#  {'C1': 'r3', 'C2': 'r2', 'C3': 'r1', 'C4': 'r4'},
#  {'C1': 'Fraud', 'C2': 'Not Fraud', 'C3': None, 'C4': None},
#  {'C1': 'Acceptable', 'C2': 'Unacceptable', 'C3': None, 'C4': None}]

# %%
row['classes_dict']
# Out:
# "{'C2': '0.72%', 'C1': '99.28%'}"

# %%
def sub_class4name(row):
    cls_ptn = re.compile("|".join([f'{k}\\b' for k in row['class2name'].keys() if k != None]))
    narr = cls_ptn.sub(lambda x: row['class2name'][x.group()], row['narration'])

# %%
def sub_class4name(row):
        cls_ptn = re.compile("|".join([f'{k}\\b' for k in row['class2name'].keys()]))


cls_ptn = re.compile("|".join([f'{k}\\b' for k in old2new_classes.keys()]))

all[i]['narration'] = cls_ptn.sub(
        lambda m: old2new_classes[re.escape(m.group(0))], all[i]['narration'])

# %%
import json

# %%
with open('../data/processed/train2.json', 'r') as f:
    train = json.load(f)

# %%
dataset['train']['unique_id'] == [t['unique_id'] for t in train]
# Out:
# True

# %%
# Out:
# [445,
#  107,
#  309,
#  237,
#  334,
#  337,
#  323,
#  295,
#  37,
#  468,
#  352,
#  8,
#  418,
#  438,
#  194,
#  421,
#  385,
#  168,
#  134,
#  94,
#  192,
#  117,
#  103,
#  163,
#  263,
#  463,
#  447,
#  307,
#  204,
#  121,
#  319,
#  449,
#  161,
#  200,
#  290,
#  164,
#  244,
#  326,
#  317,
#  185,
#  44,
#  300,
#  400,
#  224,
#  467,
#  205,
#  367,
#  424,
#  19,
#  305,
#  296,
#  284,
#  268,
#  188,
#  417,
#  203,
#  91,
#  322,
#  287,
#  116,
#  462,
#  86,
#  28,
#  330,
#  372,
#  169,
#  219,
#  85,
#  100,
#  49,
#  131,
#  48,
#  402,
#  122,
#  328,
#  3,
#  79,
#  256,
#  144,
#  384,
#  124,
#  149,
#  146,
#  465,
#  249,
#  302,
#  247,
#  186,
#  160,
#  139,
#  195,
#  408,
#  88,
#  411,
#  354,
#  254,
#  58,
#  207,
#  147,
#  336,
#  362,
#  431,
#  382,
#  57,
#  90,
#  353,
#  33,
#  355,
#  165,
#  343,
#  40,
#  240,
#  394,
#  251,
#  26,
#  55,
#  112,
#  35,
#  391,
#  260,
#  127,
#  291,
#  151,
#  133,
#  457,
#  183,
#  38,
#  17,
#  373,
#  238,
#  311,
#  380,
#  54,
#  89,
#  272,
#  455,
#  69,
#  427,
#  398,
#  143,
#  42,
#  74,
#  177,
#  0,
#  10,
#  115,
#  170,
#  338,
#  137,
#  252,
#  278,
#  221,
#  95,
#  197,
#  253,
#  128,
#  245,
#  114,
#  461,
#  306,
#  77,
#  32,
#  271,
#  388,
#  460,
#  187,
#  176,
#  437,
#  4,
#  59,
#  162,
#  175,
#  7,
#  435,
#  335,
#  211,
#  141,
#  118,
#  277,
#  208,
#  68,
#  223,
#  383,
#  129,
#  130,
#  386,
#  320,
#  239,
#  414,
#  285,
#  51,
#  13,
#  434,
#  395,
#  342,
#  241,
#  105,
#  218,
#  314,
#  222,
#  99,
#  281,
#  313,
#  182,
#  283,
#  370,
#  348,
#  157,
#  15,
#  448,
#  274,
#  104,
#  403,
#  390,
#  406,
#  196,
#  351,
#  379,
#  36,
#  312,
#  358,
#  138,
#  25,
#  29,
#  401,
#  345,
#  97,
#  442,
#  356,
#  236,
#  6,
#  106,
#  46,
#  111,
#  87,
#  5,
#  220,
#  125,
#  441,
#  315,
#  102,
#  82,
#  316,
#  136,
#  361,
#  21,
#  113,
#  324,
#  227,
#  214,
#  180,
#  212,
#  310,
#  52,
#  201,
#  140,
#  422,
#  92,
#  327,
#  9,
#  257,
#  288,
#  96,
#  27,
#  439,
#  464,
#  416,
#  294,
#  12,
#  84,
#  279,
#  142,
#  226,
#  23,
#  409,
#  357,
#  399,
#  198,
#  329,
#  45,
#  166,
#  76,
#  415,
#  230,
#  235,
#  363,
#  70,
#  67,
#  458,
#  389,
#  172,
#  231,
#  405,
#  158,
#  393,
#  246,
#  349,
#  22,
#  34,
#  178,
#  280,
#  62,
#  1,
#  350,
#  93,
#  110,
#  433,
#  318,
#  419,
#  215,
#  360,
#  72,
#  347,
#  440,
#  392,
#  150,
#  432,
#  191,
#  156,
#  425,
#  331,
#  78,
#  267,
#  20,
#  148,
#  292,
#  332,
#  61,
#  428,
#  209,
#  308,
#  339,
#  376,
#  359,
#  80,
#  16,
#  242,
#  233,
#  108,
#  60,
#  270,
#  262,
#  369,
#  234,
#  248,
#  65,
#  429,
#  73,
#  83,
#  213,
#  250,
#  225,
#  430,
#  443,
#  255,
#  299,
#  135,
#  202,
#  265,
#  286,
#  301,
#  206,
#  269,
#  346,
#  189,
#  39,
#  228,
#  466,
#  243,
#  66,
#  375,
#  31,
#  456,
#  41,
#  210]
